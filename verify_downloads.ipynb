# %%
# Verify data downloads
#
#

# %%
from os.path import join
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
datadir = "/projects/FRNN/dataset_ELM_full/"

df = pd.read_csv(join(datadir, "df_progress.csv"))

# %%
df.head()
# Out:
#    Unnamed: 0  shotnr  bmspinj  bmstinj  dssdenest  dusbradial  edensfit  \
# 0           0  187323     True     True       True        True      True
# 1           1  187324     True     True       True        True      True
# 2           2  187325     True     True       True        True      True
# 3           3  187326     True     True       True        True      True
# 4           4  187328     True     True       True        True      True
#
#    efsbetan  efsli  efswmhd  etempfit  fs07  ipeecoil  ipsiptargt  ipspr15V  \
# 0      True   True     True      True  True      True        True      True
# 1      True   True     True      True  True      True        True      True
# 2      True   True     True      True  True      True        True      True
# 3      True   True     True      True  True      True        True      True
# 4      True   True     True      True  True      True        True      True
#
# ...
