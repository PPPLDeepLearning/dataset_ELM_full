# %% [markdown]
# # Verify data downloads
# The file download.py populates a pandas dataframe that marks what signals could be downloaded for
# a shot. Sometimes signals, such as the ZIPFIT profiles edensfit, etempfit, etc..., are not done
# for various reasons. In that case no data will be pulled from MDS. After finishing the download,
# the pandas dataframe is written to a csv file. Note that the file is overwritten everytime
# download.py is executed.
#
#
# The notebook below loads this csv file.

# %%
from os.path import join
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
datadir = "/projects/FRNN/dataset_ELM_full/"

df = pd.read_csv(join(datadir, "df_progress.csv"))

# %%
df
# Out:
#      Unnamed: 0  shotnr  bmspinj  bmstinj  dssdenest  dusbradial  edensfit  \
# 0             0  187054     True     True       True        True      True
# 1             1  187055     True     True       True        True      True
# 2             2  187056     True     True       True        True      True
# 3             3  187057     True     True       True        True      True
# 4             4  187058     True     True       True        True      True
# ..          ...     ...      ...      ...        ...         ...       ...
# 195         195  187323     True     True       True        True      True
# 196         196  187324     True     True       True        True      True
# 197         197  187325     True     True       True        True      True
# 198         198  187326     True     True       True        True      True
# 199         199  187328     True     True       True        True      True
#
# ...

# %%
df[(df["bmstinj"] == True) & (df["dusbradial"] == True)]
# Out:
#      Unnamed: 0  shotnr  bmspinj  bmstinj  dssdenest  dusbradial  edensfit  \
# 0             0  187054     True     True       True        True      True
# 1             1  187055     True     True       True        True      True
# 2             2  187056     True     True       True        True      True
# 3             3  187057     True     True       True        True      True
# 4             4  187058     True     True       True        True      True
# ..          ...     ...      ...      ...        ...         ...       ...
# 195         195  187323     True     True       True        True      True
# 196         196  187324     True     True       True        True      True
# 197         197  187325     True     True       True        True      True
# 198         198  187326     True     True       True        True      True
# 199         199  187328     True     True       True        True      True
#
# ...
